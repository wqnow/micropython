# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/wqnow/micropython/blob/master/keras_learning20180609.ipynb)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
a = np.linspace(0,1,101)
b = a ** 2

# %%
plt.plot(a,b)
